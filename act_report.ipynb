# %% [markdown]
# # Analyzing and Visualizing @dog_rates
# (Dataset from Twitter account)
#  Ekaterina Kuznetsova, 21.12.21

# %% [markdown]
# ### Introduction:
# WeRateDogs is a Twiiter account, that let people to rate dogs with a funny comment.
# The account was started at 2015 by student Matt Nelson and nowadays (21.12.2021) has 9,1 Million followers and 14,8K tweets.
# But why it is so popular? One of the reasons is that the numerators are often greater than 10 (11/10,12/10, 14/10 as in the screenschot…)
# Here is an example from https://twitter.com/dog_rates:

# %%
from IPython.display import Image
Image("dog.png")

# %% [markdown]
# ## Data analysis and visualisation:
# Before we starting with Visualization and Analysis we are Wrangling and Cleaning our dataset.

# %% [markdown]
# ## 1.	The most favourite dog type?

# %%
Image("1.png")

# %%
Image("1_2.png")

# %% [markdown]
# #### Insight 1:
# Most of dogs were not_specified (1035), which significantly exceeds significant dog stages. Puppers is 140, doggo - 52, puppo - 19 and floofer just 3.

# %% [markdown]
# ## 2. Which dog breed are most rated?

# %%
Image("2.png")

# %% [markdown]
# Insight 2:
# Top 5 most rated breeds: 1.Golden Retriever 2. Labrador Retriver 3. Pembroke 4. Chichuahua 5.Pug

# %% [markdown]
# ## 3. Which words are more popular?

# %%
Image("3.png")

# %% [markdown]
# ####  Insight 3:
#
#
# Most popular words we can roughtly devide into 4 parts:
# 1. Group of words with dog,pyppy, puppo, doggo, pet etc. (which i not used for thiis word cloud)
# 2. Action verbs: meet, say, hang, stop, enjoy etc.
# 3. Adjectives for dogs, such as: happy, poor, magical...
# 4. Nouns: bone, eyek, life, smile...

# %% [markdown]
# ## 3. Which names are more popular?

# %%
Image("4.png")

# %% [markdown]
# #### Insight 4:
# Top 5 dogs name:
# 1. Penny, 2.Oliver,3.Lucy, 4.Cooper, 5.Charlie
